# %%
import pandas as pd

df = pd.read_csv('dataset.csv')
df
# Out:
#                              Character            Power_Level  \
# 0                                 Goku                     10
# 1                                Bulma                    1.5
# 2                           Bear Thief                      7
# 3                         Master Roshi                     30
# 4                               Oolong                      5
# ...                                ...                    ...
# 1239     Goku (MSSJ with SSJG's power)     22,400,000,000,000
# 1240                       Goku (SSJG)    224,000,000,000,000
# 1241                              Goku         44,800,000,000
# 1242  Beerus (full power, never shown)    896,000,000,000,000
# 1243    Whis (full power, never shown)  4,480,000,000,000,000
#
#                  Saga_or_Movie Dragon_Ball_Series
# 0           Emperor Pilaf Saga        Dragon Ball
# 1           Emperor Pilaf Saga        Dragon Ball
# 2           Emperor Pilaf Saga        Dragon Ball
# ...

# %%
# Solo Saga's
filtro_namek = df[df['Saga_or_Movie'] == 'Namek Saga']
filtro_force = df[df['Saga_or_Movie'] == 'Ginyu Force Saga']
filtro_ginyu = df[df['Saga_or_Movie'] == 'Captain Ginyu Saga']
filtro_freezer = df[df['Saga_or_Movie'] == 'Frieza Saga']

filtro_namek['Power_Level'] = filtro_namek['Power_Level'].replace(',', '', regex=True).astype(float)
filtro_force['Power_Level'] = filtro_force['Power_Level'].replace(',', '', regex=True).astype(float)
filtro_ginyu['Power_Level'] = filtro_ginyu['Power_Level'].replace(',', '', regex=True).astype(float)
filtro_freezer['Power_Level'] = filtro_freezer['Power_Level'].replace(',', '', regex=True).astype(float)

filtro_namek = filtro_namek.sort_values('Power_Level', ascending=False)
filtro_force = filtro_force.sort_values('Power_Level', ascending=False)
filtro_ginyu = filtro_ginyu.sort_values('Power_Level', ascending=False)
filtro_freezer = filtro_freezer.sort_values('Power_Level', ascending=False)

filtro_freezer = filtro_freezer.drop([274,269,271,273,265,272,258,255,260,259,262,261,252,256,257,268,250], axis='index').head(8)
filtro_freezer = filtro_freezer.replace('Frieza (100% power)','Freezer (100%)')
filtro_freezer = filtro_freezer.replace('Frieza','Freezer')
filtro_freezer = filtro_freezer.replace('Frieza (final form)','Freezer (Forma final)')
filtro_freezer = filtro_freezer.replace('Gohan (angry)','Gohan (Enojado)')
filtro_freezer = filtro_freezer.replace("Piccolo (Gohan and Krillin's energy)",'Piccolo')

filtro_ginyu = filtro_ginyu.drop([219,217,218,223,227,228], axis='index')
filtro_ginyu = filtro_ginyu.replace('Frieza (calm)','Freezer (Calmado)')
filtro_ginyu = filtro_ginyu.replace('Ginyu (full power)','Ginyu')

filtro_force = filtro_force.drop([210,216,208,201,206,203,202,212], axis='index').head(20)
filtro_force = filtro_force.replace('Gohan (angry)','Gohan (Enojado)')

filtro_namek = filtro_namek.drop(193, axis='index').head(8)
filtro_namek = filtro_namek.replace('Frieza (calm)','Freezer (Calmado)')
filtro_namek = filtro_namek.replace('Zarbon (transformed)','Zarbon Monstruo')
filtro_namek = filtro_namek.replace('Nail (suppressed)','Nail (Restringido)')
filtro_namek = filtro_namek.replace('Gohan (potential unlocked)','Gohan')


filtro_namek.to_csv('namek.csv')
filtro_force.to_csv('force.csv')
filtro_ginyu.to_csv('ginyu.csv')
filtro_freezer.to_csv('freezer.csv')
# Out:
# C:\Users\ursar\AppData\Local\Temp\ipykernel_4852\2630031444.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro_namek['Power_Level'] = filtro_namek['Power_Level'].replace(',', '', regex=True).astype(float)
# C:\Users\ursar\AppData\Local\Temp\ipykernel_4852\2630031444.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro_force['Power_Level'] = filtro_force['Power_Level'].replace(',', '', regex=True).astype(float)
# ...
